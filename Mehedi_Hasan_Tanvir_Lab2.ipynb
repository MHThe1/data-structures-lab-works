# %%
ourarr = [[""]*10, [""]*10]
flag = True
text1 = input("Enter the top ad: ")
if len(text1)<=10:
  for i in range(len(text1)):
    ourarr[0][i]=text1[i]

else:
  flag = False

text2 = input("Enter the bottom ad: ")
if len(text2)<=10:
  for i in range(len(text2)):
    ourarr[1][i]=text2[i]
else:
  flag = False

if flag == True:
  #starting index
  def Stidx(garr):
    sti = 0
    for i in range(len(garr)):
      if 65 <= ord(garr[i]) <= 90:
        sti = i
    return sti
  st1 = Stidx(ourarr[0])
  st2 = Stidx(ourarr[1])
  
  #starting character
  def Stc(garr):
    stic = ""
    for i in range(len(garr)):
      if 65 <= ord(garr[i]) <= 90:
        stic = garr[i]
    return stic
  st1c = Stc(ourarr[0])
  st2c = Stc(ourarr[1])

  print("Top board's first index:", st1)
  print("Top board's first character:", st1c)
  print("Bottom board's first index:", st2)
  print("Bottom board's first character:", st2c)

  pidx1 = st1
  pidx2 = st2
  userinp = input("To continue press any key other than Q/q. Press Q/q to exit.")

  while userinp!='Q' and userinp!='q':
    np1 = pidx1
    for i in range(len(ourarr[0])):
      print(ourarr[0][np1], end="")
      np1 = ((np1 - 1)+ len(ourarr[0])) % len(ourarr[0])
    pidx1 = ((pidx1 - 1)+ len(ourarr[0])) % len(ourarr[0])
    print("")

    np2 = pidx2
    for i in range(len(ourarr[1])):
      print(ourarr[1][np2], end="")
      np2 = ((np2 + 1)+ len(ourarr[1])) % len(ourarr[1])
    pidx2 = ((pidx2 + 1)+ len(ourarr[1])) % len(ourarr[1])
    print("")
    userinp = input("To continue press any key other than Q/q. Press Q/q to exit.")

  #reassigning again to showcase that the process didn't change the arrays, I acknowledge that it is uneccessary to do so though
  st1 = Stidx(ourarr[0])
  st2 = Stidx(ourarr[1])
  st1c = Stc(ourarr[0])
  st2c = Stc(ourarr[1])
  print("Top board's first index:", st1)
  print("Top board's first character:", st1c)
  print("Bottom board's first index:", st2)
  print("Bottom board's first character:", st2c)
else:
  print("Invalid Input Size")
# Out:
# Enter the top ad: giRtfel2th
# Enter the bottom ad: rightLeft2
# Top board's first index: 2
# Top board's first character: R
# Bottom board's first index: 5
# Bottom board's first character: L
# To continue press any key other than Q/q. Press Q/q to exit.g
# Right2left
# Left2right
# To continue press any key other than Q/q. Press Q/q to exit.j
# ight2leftR
# eft2rightL
# To continue press any key other than Q/q. Press Q/q to exit.k
# ght2leftRi
# ft2rightLe
# To continue press any key other than Q/q. Press Q/q to exit.f
# ht2leftRig
# t2rightLef
# To continue press any key other than Q/q. Press Q/q to exit.s
# t2leftRigh
# 2rightLeft
# To continue press any key other than Q/q. Press Q/q to exit.r
# 2leftRight
# rightLeft2
# To continue press any key other than Q/q. Press Q/q to exit.q
# Top board's first index: 2
# Top board's first character: R
# Bottom board's first index: 5
# Bottom board's first character: L
